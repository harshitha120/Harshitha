# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-4f30049a-ca39-47ef-9d66-549fc4863fde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f30049a-ca39-47ef-9d66-549fc4863fde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid.csv to covid.csv

# %%
import io
data = pd.read_csv(io.BytesIO(uploaded['covid.csv']))
data.head()
# Out:
#    Unnamed: 0                 date state  ...  casi_testati  note_it  note_en
# 0           0  2020-02-24T18:00:00   ITA  ...           NaN      NaN      NaN
# 1           1  2020-02-25T18:00:00   ITA  ...           NaN      NaN      NaN
# 2           2  2020-02-26T18:00:00   ITA  ...           NaN      NaN      NaN
# 3           3  2020-02-27T18:00:00   ITA  ...           NaN      NaN      NaN
# 4           4  2020-02-28T18:00:00   ITA  ...           NaN      NaN      NaN
#
# [5 rows x 17 columns]

# %%
#To get list of all columns
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'variation_total_confirmed',
#        'new_confirmed_cases', 'recovered', 'deaths', 'total_cases',
#        'swabs_made', 'casi_testati', 'note_it', 'note_en'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Unnamed: 0  hospitalized_with_symptoms  ...    swabs_made  casi_testati
# count   70.000000                   70.000000  ...  7.000000e+01  1.500000e+01
# mean    34.500000                17373.142857  ...  6.873203e+05  1.195250e+06
# std     20.351085                10475.956363  ...  6.689012e+05  1.790798e+05
# min      0.000000                  101.000000  ...  4.324000e+03  9.353100e+05
# 25%     17.250000                 6844.000000  ...  8.888025e+04  1.034036e+06
# 50%     34.500000                20522.500000  ...  4.656945e+05  1.210639e+06
# 75%     51.750000                27262.750000  ...  1.163153e+06  1.334180e+06
# max     69.000000                29010.000000  ...  2.153772e+06  1.456911e+06
#
# [8 rows x 13 columns]

# %%
#to check for Null values
data.isnull().sum()
# Out:
# Unnamed: 0                     0
# date                           0
# state                          0
# hospitalized_with_symptoms     0
# intensive_care                 0
# total_hospitalized             0
# home_quarantine                0
# total_confirmed_cases          0
# variation_total_confirmed      0
# new_confirmed_cases            0
# recovered                      0
# deaths                         0
# total_cases                    0
# swabs_made                     0
# casi_testati                  55
# note_it                       52
# note_en                       52
# dtype: int64

# %%
#realating the variables with scatter plots
#Visualization of data

# %%
#total confirmed cases vs recovered cases
sns.relplot(x="total_confirmed_cases",y="recovered",data=data)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'variation_total_confirmed',
#        'new_confirmed_cases', 'recovered', 'deaths', 'total_cases',
#        'swabs_made', 'casi_testati', 'note_it', 'note_en'],
#       dtype='object')

# %%
#total cases vs total deaths
sns.relplot(x='total_confirmed_cases',y='deaths',data=data)

# %%
#relation between total cases vs total confirmed cases
sns.relplot(x="total_cases",y="total_confirmed_cases",data=data)

# %%
sns.relplot(x="total_confirmed_cases",y="hospitalized_with_symptoms",hue='recovered',data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='total_cases',y='home_quarantine',kind='line',data=data)

# %%
sns.relplot(x='recovered',y='home_quarantine',kind='line',data=data)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'variation_total_confirmed',
#        'new_confirmed_cases', 'recovered', 'deaths', 'total_cases',
#        'swabs_made', 'casi_testati', 'note_it', 'note_en'],
#       dtype='object')

# %%
sns.catplot(x='recovered',y='total_cases',data=data)

# %%
#conclusions drawn:
#There is increase in number of recovered patients
#There is also increase in number of deaths with more numbers of cases reported
#We can flatten of curve with people home quartining or staying at home and we can see drop in number of cases.
