# %%
#Declare an int value and store it in a variable. 
a=10



#Check the type and print the id of the same.
print(type(a))
print(id(a))
# Out:
# <class 'int'>
# 10914784

# %%
#Take one int value between 0 - 256.
#Assign it to two different variables.
#Check the id of both the variables. It should come same. Check why?
a=234
b=234
print(id(a))
print(id(b))
#explanation:This is due to object reusability concept.here both variables a and b will be pointing to the same memory loaction where 234 is stored.
#object reusability works for integers in the range of -5 to 256



#Take one int value either less than -5 or greater than 256.
#Assign it to two different variables.
#Check the id of both the variables. It should come different.Check why?
a1=-6
b1=-6
print(id(a1))
print(id(b1))
#Explanation: For integers object reusability concept within the range of -5 to 256
#and here a1 and b1 are out of this range ..thus object reusability concept work and both a1 and b1 has two different ids.
# Out:
# 10921952
# 10921952
# 139660076072400
# 139660076071920

# %%
#Arithmatic Operations on integers
#Take two different intger values.
#Store them in two different variables.
#Do below operations on them:-
    #Find sum of both number
    #Find differce between them
    #Find the product of both numbers.
    #Find value after dividing first num with second number
    #Find the remainder after dividing first number with second number
    #Find the quotient after dividing first number with second number
    #Find the result of first num to the power of second number.

a=20
b=10
#sum of both number
sum=a+b
print(sum)
#difference of both number
difference=a-b
print(difference)
#product of two numbers
product=a*b
print(product)
#division
div=a/b
print(div)
#modulus
modulo=a%b
print(modulo)
#quotient
quotient=a/b
print(quotient)
#power
pow=a**b
print(pow)
# Out:
# 30
# 10
# 200
# 2.0
# 0
# 2.0
# 10240000000000

# %%
#Comparison Operators on integers
#Take two different intger values.
#Store them in two different variables.
#Do below operations on them:-
    #Compare se two numbers with below operator:-
        #Greater than, '>'
        #Smaller than, '<'
        #Greater than or equal to, '>='
        #Less than or equal to, '<='
#Observe their output(return type should be boolean)

c=23
d=45
print(c>d)
print(c<d)
print(c>=d)
print(c<=d)
# Out:
# False
# True
# False
# True

# %%
#Equality Operator
#Take two different intger values.
#Store them in two different variables.
#Equuate them using equality operator (==, !=)
#Observe the output(return type should be boolean)
c1=3
d1=5
c3=3
print(c1==c3)
print(d1==c3)
print(c1!=c3)
# Out:
# True
# False
# False

# %%
#Logical operators
#Observe the output of below code
#Cross check the output manually

print(10 and 20)       #----------------------------------------->Output is 20
print(0 and 20)        #----------------------------------------->Output is 0
print(20 and 0)        #----------------------------------------->Output is 0
print(0 and 0)         #----------------------------------------->Output is 0

print(10 or 20)        #----------------------------------------->Output is 10
print(0 or 20)         #----------------------------------------->Output is 20
print(20 or 0)         #----------------------------------------->Output is 20
print(0 or 0)          #----------------------------------------->Output is 0

print(not 10)          #----------------------------------------->Output is False
print(not 0)           #----------------------------------------->Output is True

#10 and 20------>o/p:20
#0 and 20------->o/p:0
#20 and 0------->o/p:0
#0 and 0-------->o/p:0
#10 or 20------->o/p:20
#0 or 20-------->o/p:20
#20 or 0-------->o/p:20
#0 or 0---------->0/p:0
#not 10--------->o/p:False
#not 0---------->o/p:True
# Out:
# 20
# 0
# 0
# 0
# 10
# 20
# 20
# 0
# False
# True

# %%
#Bitwise Operators
#Do below operations on the values provided below:-
    #Bitwise and(&) -----------------------------------------> 10, 20   -------> Output is 0.    
    #Bitwise or(|)  -----------------------------------------> 10, 20   -------> Output is 30
    #Bitwise(^)     -----------------------------------------> 10, 20   -------> Output is 30
    #Bitwise negation(~) ------------------------------------> 10       -------> Output is -11
    #Bitwise left shift  ------------------------------------> 10,2     -------> Output is 40
    #Bitwise right shift ------------------------------------> 10,2     -------> Output is 2
#Cross check the output manually
#bit wise and(&)-------->10: 1010
                         20:10100
                       #o/p:00000------>0 
#bit wise or(|)--------->10: 1010
                         20:10100
                       #o/p:11110------->30
#bit wise (^)----------->10: 1010
                         20:10100
                       #o/p:11110------->30     
#bitwise negation(~)------->10: 1010----(-(10+1))=(-11)
                           #o/p:-1011---->-11    
#bit wise left shift------->10:1010
                          #o/p:101000----->40
#bit wise right shift------->10:1010
                          #o/p: 1000------>2

# %%
#What is the output of expression inside print statement. Cross check before running the program.
a = 10
b = 10
print(a is b)          #True or False?-------> true
print(a is not b)      #True or False?--------> false

a = 1000
b = 1000
print(a is b)          #True or False? -------->false 
print(a is not b)      #True or False? --------->true

# %%
#What is the output of expression inside print statement. Cross check before running the program.
print(10+(10*32)//2**5&20+(~(-10))<<2) #o/p:20

# %%
#Membership operation
#in, not in are two membership operators and it returns boolean value

print('2' in 'Python2.7.8')                  #true
print(10 in [10,10.20,10+20j,'Python'])     #true
print(10 in (10,10.20,10+20j,'Python'))     #true
print(2 in {1,2,3})                            #true
print(3 in {1:100, 2:200, 3:300})              #true 
print(10 in range(20))                         #true
# Out:
# True
# True
# True
# True
# True
# True

# %%
#An integer can be represented in binary, octal or hexadecimal form.
#Declare one binary, one octal and one hexadecimal value and store them in three different variables.
#Convert 9876 to its binary, octal and hexadecimal equivalent and print their corresponding value.

# %%
#What will be the outut of following:-
a = 0b1010000   #o/p:80
print(a)

b = 0o7436    #o/p:3870
print(b)

c = 0xfade    #o/p:64222
print(c)

print(bin(80))  #o/p:0b1010000

print(oct(3870))  #o/p:0o7436

print(hex(64222))   #o/p:0xfade

print(bin(0b1010000)) #o/p:0b1010000

print(bin(0xfade))    #o/p:0b1111101011011110

print(oct(0xfade))     #0/p:0o175336

print(oct(0o7436))    #o/p:0o7436

print(hex(0b1010000))  #o/p:0x50

print(hex(0xfade))   #0/p:0xfade
# Out:
# 80
# 3870
# 64222
# 0b1010000
# 0o7436
# 0xfade
# 0b1010000
# 0b1111101011011110
# 0o175336
# 0o7436
# 0x50
# 0xfade
